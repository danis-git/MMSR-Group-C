# %%
import numpy as np
import pandas as pd
from numpy.linalg import norm

# %%
# change the file path here
file_path_base = #r"C:\Users\Richard\Desktop\JKU\1.Semester-WS2023\MultimediaSearchAndRetrieval\\"
file_path_info = file_path_base + "id_information_mmsr.tsv" 
file_path_word2vec = file_path_base + "id_lyrics_word2vec_mmsr.tsv"
file_path_tfidf = file_path_base + "id_lyrics_tf-idf_mmsr.tsv"
file_path_bert = file_path_base + "id_lyrics_bert_mmsr.tsv"

df_info = pd.read_table(file_path_info)
df_word2vec = pd.read_table(file_path_word2vec)
df_tfidf = pd.read_table(file_path_tfidf)
df_bert = pd.read_table(file_path_bert)

df_info
# Out:
#                      id                       artist  \
# 0      01Yfj2T3YTwJ1Yfy                  We As Human
# 1      01gyRHLquwXDlhkO         The Notorious B.I.G.
# 2      01rMxQv6vhyE1oQX          Against the Current
# 3      02RGE9FNH65RtMS7                     Barthezz
# 4      02ZnlCGZEbkfCDxo                Laura Pausini
# ...                 ...                          ...
# 10090  zyzILCQvVeUFIINi                Crowded House
# 10091  zzgS4ZqyswamEWNj               Britney Spears
# 10092  zzoFYDMlqU1X2zz1                   Thundercat
# 10093  zzpkRCGA5ud8q4mv                 Otis Redding
# 10094  zzx8CWdM7qkxKQpC  Ted Leo and the Pharmacists
#
#                                             song  \
# 0      Take The Bullets Away (feat. Lacey Sturm)
# 1                           Somebody's Gotta Die
# 2                                 Chasing Ghosts
# 3                                       Infected
# 4                               Tra Te E Il Mare
# ...                                          ...
# 10090                              When You Come
# 10091                   My Only Wish (This Year)
# 10092                                        DUI
# 10093                               Rock Me Baby
# 10094                    Counting Down the Hours
#
#                                         album_name
# 0                                      We As Human
# 1            Life After Death (Remastered Edition)
# 2                                     In Our Bones
# 3             Trance - The Early Years (1997-2002)
# 4      The Best of Laura Pausini - E Ritorno Da Te
# ...                                            ...
# 10090                            Temple Of Low Men
# 10091                           Platinum Christmas
# 10092                                        Drunk
# 10093                                    Otis Blue
# 10094                             Shake the Sheets
#
# [10095 rows x 4 columns]

# %%
# Random base line
N = 10

def random_baseline(data: pd.DataFrame, title: str, artist: str, n: int) -> pd.DataFrame:
    return df_info.sample(n=n)[["id","artist","song"]]
    
random_baseline(df_info, "My Only Wish (This Year)", "Britney Spears", N)
# Out:
#                     id                 artist                     song
# 5951  arFact5frY7Il4l3          Mylène Farmer             Sans Logique
# 1740  ASZ3TvYABS68ym1Y                Emicida  Fica Mais um Pouco Amor
# 2950  Ht4qhPvFoG95vSSj                   Blur              Trailerpark
# 6452  dvoBuh4D2rKLvp0R              Sugar Ray                  Someday
# 648   3puEiVevhqrziT7t                 Selena               Si Una Vez
# 5207  W1KQe9A1SdbULx79             Luke Combs       This One's for You
# 1906  BRTTbs2WbkBKHynj           Dimmu Borgir   Alt Lys Er Svunnet Hen
# 6921  giggjHlusqieNE8L          Mary J. Blige               MJB Da MVP
# 8776  rrrGRm9YfqdZmItY            Jessie Ware         Champagne Kisses
# 911   5PsAhyXTxQowhIUu  Donavon Frankenreiter               On My Mind

# %%
def cos_sim(query: [int], target: [int]) -> int:
    return np.dot(query,target)/(norm(query)*norm(target))

def euclid_dist(query: [int], target: [int]) -> int:
    return norm(query-target)
  
def text_based_retrieval(info: pd.DataFrame, feature: pd.DataFrame, title: str, artist: str, n: int, sim_func = cos_sim, ascending=False) -> pd.DataFrame:
    feature_no_id = feature.drop(columns="id") # drop id column for similarity measurement
    query = info[(info["artist"] == artist) & (info["song"] == title)]["id"].values[0] # search for song in info
    query = feature[feature["id"]==query].drop(columns="id") # get feature vector for song
    sims = [sim_func(query, target) for target in feature_no_id.values] # compute similarity between query and each target song

    info["sim"] = sims
    info_sorted=info.sort_values(by=["sim"], ascending=ascending)
    return info_sorted[["id","artist","song"]][1:n+1] # skips the first row, because it is the query track

# %%
# Text-based(cos-sim, tf-idf)
text_based_retrieval(df_info, df_tfidf, "Jingle Bells", "Frank Sinatra", 10)
# Out:
#                     id                 artist  \
# 2778  GvR3ihpANzPFUV9q              Ryan Star
# 6220  cZq0NEOrY3Ub5Bqc           All Time Low
# 1299  7o67ctY7Qo945yfv  The Smashing Pumpkins
# 8221  oUaMwbrwMD9grrIA                 Mayhem
# 5240  WESZfNkEXTSzBsaH        Love Generation
# 8349  pH97idDxXVlnq3xH           Dixie Chicks
# 8105  nkmwTJvccNwNK8mo                  Suede
# 9543  wYoJBT9Lg1bBf8Nd                   Moby
# 2856  HMvRdVsvXUPwROWw            Title Fight
# 4039  OqVFiTyVf5wR5FNq         Brandi Carlile
#
#                                     song
# 2778                       We Might Fall
# 6220        Merry Christmas, Kiss My Ass
# 1299                The Everlasting Gaze
# 8221  Crystalized Pain In Deconstruction
# 5240                         Dance Alone
# 8349                         Loving Arms
# 8105            The Chemistry Between Us
# 9543               One Of These Mornings
# 2856                         Liar's Love
# 4039                Late Morning Lullaby

# %%
# Text-based(cos-sim, bert)
text_based_retrieval(df_info, df_bert, "Jingle Bells", "Frank Sinatra", 10)
# Out:
#                     id           artist                       song
# 2778  GvR3ihpANzPFUV9q        Ryan Star              We Might Fall
# 4257  QBGxad2tXIjeAZmP         Nevilton                Pressuposto
# 3128  J3Y3E5wh2TcJcUGM    Steel Panther     Death To All But Metal
# 1379  8DxVQ1vrjsNTIqOv  New Found Glory        My Friends Over You
# 2423  EeUoJbeUQNiHGJeX            Angra                    Caveman
# 1758  AZGxAypdz7mBmx1R    Emilie Autumn                   Opheliac
# 1756  AYxLbkF55hvueDLM    Gloria Groove                  Coisa Boa
# 9804  y3WWGqthYTQjP7uM     Eddie Vedder                    Goodbye
# 451   2ZFMLcQ9rWNndcLi      Jane Weaver         Don't Take My Soul
# 5420  XLT9XQT48DfHAZEc       Elton John  No Shoe Strings On Louise

# %%
# Text-based(euclidean distance, tf-idf)
text_based_retrieval(df_info, df_tfidf, "Jingle Bells", "Frank Sinatra", 10, euclid_dist, True)
# Out:
#                     id                 artist  \
# 2778  GvR3ihpANzPFUV9q              Ryan Star
# 6220  cZq0NEOrY3Ub5Bqc           All Time Low
# 1299  7o67ctY7Qo945yfv  The Smashing Pumpkins
# 8221  oUaMwbrwMD9grrIA                 Mayhem
# 5240  WESZfNkEXTSzBsaH        Love Generation
# 8349  pH97idDxXVlnq3xH           Dixie Chicks
# 8105  nkmwTJvccNwNK8mo                  Suede
# 9543  wYoJBT9Lg1bBf8Nd                   Moby
# 2856  HMvRdVsvXUPwROWw            Title Fight
# 4039  OqVFiTyVf5wR5FNq         Brandi Carlile
#
#                                     song
# 2778                       We Might Fall
# 6220        Merry Christmas, Kiss My Ass
# 1299                The Everlasting Gaze
# 8221  Crystalized Pain In Deconstruction
# 5240                         Dance Alone
# 8349                         Loving Arms
# 8105            The Chemistry Between Us
# 9543               One Of These Mornings
# 2856                         Liar's Love
# 4039                Late Morning Lullaby
